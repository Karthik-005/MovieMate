# %%
import os
import requests
import time
from dotenv import load_dotenv
from collections import defaultdict

# %%
load_dotenv()

api_key = os.getenv("TMDB_API_KEY")

if api_key:
    print("API key is successfully loaded")
else:
    print("Error loading the api key")
# Out:
# API key is successfully loaded

# %%
dataset = defaultdict(list)

# %%
base_url = "https://api.themoviedb.org/3"

# %%
def fetch_data(base_url, dataset, page=1):
    movies_endpoint = "/discover/movie"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjMDEyZDNlOGFiZWZhYTU3M2U1YjhkZGQ3MWFhYmU1MiIsIm5iZiI6MTc3MzE3MjQ4NS43MDg5OTk5LCJzdWIiOiI2OWIwNzcwNTJiNmFmZjZkMzcxMWVhYjIiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.yQJPjdE-OtV-anwg9AhGGBhR6605TmhCe_AJLeL-QWI"
    }

    params = {
        "api_key" : api_key,
        "sort_by" : "popularity.desc",
        "vote_count.gte" : 1000,
        "page":page
    }

    try:
        response = requests.get(base_url+movies_endpoint, 
                                headers=headers, 
                                params=params,
                                verify=False)
        
        if response.status_code != 200:
            print(f"request failed, status code : {response.status_code}")
            
    except Exception as e:
        print(f"{e}")
        
    data = response.json()

    for movie in data['results']:
        dataset['Movie_ID'].append(movie['id'])
        dataset['Title'].append(movie['original_title'])
        dataset['Rating'].append(movie['vote_average'])
        dataset['Data_of_release'].append(movie['release_date'])
        dataset['Genre_IDs'].append(movie['genre_ids'])
        dataset['Plot'].append(movie['overview'])
    print(f"Page-{page} done!")

# %%
for i in range(1,51):
    fetch_data(base_url, dataset, i)
    time.sleep(0.5)
# Out:
# /home/karthik/Documents/college/NLP/CineBot/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Page-1 done!
# /home/karthik/Documents/college/NLP/CineBot/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.themoviedb.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Page-2 done!
# ...

# %%
len(dataset['Movie_ID'])
